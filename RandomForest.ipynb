# %% [markdown]
# # **Préparation des données**

# %%
import pandas as pd

# %%
#Chargement de données
df = pd.read_csv("balanced_data.csv")
print(df.shape)
df.head()
# Out:
# (1629, 50)
#    Unnamed: 0  patient_id month_visit day_visit  year_visit  \
# 0           0         2.0       April    Monday      2020.0
# 1           1        10.0       April  Thursday      2020.0
# 2           2        12.0       April  Thursday      2020.0
# 3           3        16.0       April  Saturday      2020.0
# 4           4        20.0       April    Sunday      2020.0
#
#   is_arrival_ambulance  heart_rate_signal ambulance_time  patient_age  \
# 0                  Yes              106.0           28.0         64.0
# 1                  Yes               72.0           24.0         23.0
# 2                  Yes              101.0           38.0         50.0
# 3                  Yes              110.0           74.0         61.0
# 4                  Yes              112.0           47.0         32.0
#
#   patient_sexe  ...    medicament2      medicament3    medicament4  \
# 0         Male  ...         VANTIN    NO ENTRY MADE  NO ENTRY MADE
# 1         Male  ...  NO ENTRY MADE    NO ENTRY MADE  NO ENTRY MADE
# 2         Male  ...         VERSED    NO ENTRY MADE  NO ENTRY MADE
# 3         Male  ...  NO ENTRY MADE    NO ENTRY MADE  NO ENTRY MADE
# 4         Male  ...         OXYGEN  SODIUM CHLORIDE        TYLENOL
#
#                 is_med1_given_emergency               is_med2_given_emergency  \
# 0                       RX at discharge              Both given and RX marked
# 1  Not applicable, no medication listed  Not applicable, no medication listed
# 2                          Given in  ED                          Given in  ED
# 3                          Given in  ED  Not applicable, no medication listed
# 4                          Given in  ED                          Given in  ED
#
#                 is_med3_given_emergency               is_med4_given_emergency  \
# 0  Not applicable, no medication listed  Not applicable, no medication listed
# 1  Not applicable, no medication listed  Not applicable, no medication listed
# 2  Not applicable, no medication listed  Not applicable, no medication listed
# 3  Not applicable, no medication listed  Not applicable, no medication listed
# 4                          Given in  ED              Both given and RX marked
#
#                   number_medicaments_given_emergency  \
# 0                                                1.0
# 1  None listed/listed drug Rx at discharge only o...
# 2                                                2.0
# 3                                                1.0
# 4                                                4.0
#
#                   number_medicaments_given_discharge polarity_health_status
# 0                                                2.0                      2
# 1  None listed/listed drug given at ED only or un...                      2
# 2  None listed/listed drug given at ED only or un...                      2
# 3  None listed/listed drug given at ED only or un...                      2
# 4                                                1.0                      2
#
# [5 rows x 50 columns]

# %%
#Supprimer les colonnes dangereuses Ces colonnes donnent déjà la réponse au modèle → interdites.
leak_cols = [
    "polarity_health_status",
    "is_med1_given_emergency",
    "is_med2_given_emergency",
    "is_med3_given_emergency",
    "is_med4_given_emergency",
    "number_medicaments_given_emergency"
]

df = df.drop(columns=[c for c in leak_cols if c in df.columns])

# %%
df.head()
# Out:
#    Unnamed: 0  patient_id month_visit day_visit  year_visit  \
# 0           0         2.0       April    Monday      2020.0
# 1           1        10.0       April  Thursday      2020.0
# 2           2        12.0       April  Thursday      2020.0
# 3           3        16.0       April  Saturday      2020.0
# 4           4        20.0       April    Sunday      2020.0
#
#   is_arrival_ambulance  heart_rate_signal ambulance_time  patient_age  \
# 0                  Yes              106.0           28.0         64.0
# 1                  Yes               72.0           24.0         23.0
# 2                  Yes              101.0           38.0         50.0
# 3                  Yes              110.0           74.0         61.0
# 4                  Yes              112.0           47.0         32.0
#
#   patient_sexe  ... is_patient_suffer_high_cholesterol  \
# 0         Male  ...                                 No
# 1         Male  ...                                 No
# 2         Male  ...                                 No
# 3         Male  ...                                 No
# 4         Male  ...                                Yes
#
#    is_patient_suffer_hyper_tension  is_patient_suffer_obesity  \
# 0                              Yes                         No
# 1                              Yes                         No
# 2                               No                         No
# 3                              Yes                         No
# 4                              Yes                        Yes
#
#    is_patient_suffer_apnea  is_patient_suffer_osteoporosis    medicament1  \
# 0                       No                              No         FLOMAX
# 1                       No                              No  NO ENTRY MADE
# 2                       No                              No         OXYGEN
# 3                       No                              No        ASPIRIN
# 4                       No                              No         KEPPRA
#
#      medicament2      medicament3    medicament4  \
# 0         VANTIN    NO ENTRY MADE  NO ENTRY MADE
# 1  NO ENTRY MADE    NO ENTRY MADE  NO ENTRY MADE
# 2         VERSED    NO ENTRY MADE  NO ENTRY MADE
# 3  NO ENTRY MADE    NO ENTRY MADE  NO ENTRY MADE
# 4         OXYGEN  SODIUM CHLORIDE        TYLENOL
#
#                   number_medicaments_given_discharge
# 0                                                2.0
# 1  None listed/listed drug given at ED only or un...
# 2  None listed/listed drug given at ED only or un...
# 3  None listed/listed drug given at ED only or un...
# 4                                                1.0
#
# [5 rows x 44 columns]

# %%
#Transformer le statut patient en chiffres
df["patient_health_status"] = df["patient_health_status"].map({
    "Emergent": 0,
    "Semi-urgent": 1,
    "Urgent": 2
})

# %%
#Supprimer les lignes vide
df = df.dropna(subset=["patient_health_status"])

# %%
#Vérifier le nombre de patients par classe
print(df["patient_health_status"].value_counts())
# Out:
# patient_health_status
# 2    543
# 0    543
# 1    543
# Name: count, dtype: int64

# %%
#Séparer X (entrées) et y (sortie)
X = df.drop(columns=["patient_health_status"])
y = df["patient_health_status"]

# %%
#Séparer colonnes numériques et texte
cat_cols = X.select_dtypes(include=["object"]).columns.tolist()
num_cols = [c for c in X.columns if c not in cat_cols]

print("Colonnes texte :", cat_cols)
print("Colonnes numériques :", num_cols)
# Out:
# Colonnes texte : ['month_visit', 'day_visit', 'is_arrival_ambulance', 'ambulance_time', 'patient_sexe', 'patient_race', 'patient_pain_category', 'is_patient_seen_before_72h', 'patient_alchol_level', 'is_patient_suffer_alzheimar', 'is_patient_suffer_cancer', 'is_patient_suffer_cerebrovascular', 'is_patient_suffer_chronic_kidney', 'is_patient_suffer_chronic_obstructive_pulmonary', 'is_patient_suffer_congestive_heart_failure', 'is_patient_suffer_coronary_artery', 'is_patient_suffer_depression', 'is_patient_suffer_diabet_L1', 'is_patient_suffer_diabet_L2', 'is_patient_suffer_diabet_L0', 'is_patient_suffer_renal_insufficiency', 'is_patient_suffer_pulmonary_embolism', 'is_patient_suffer_HIV_infection', 'is_patient_suffer_high_cholesterol', 'is_patient_suffer_hyper_tension', 'is_patient_suffer_obesity', 'is_patient_suffer_apnea', 'is_patient_suffer_osteoporosis', 'medicament1', 'medicament2', 'medicament3', 'medicament4', 'number_medicaments_given_discharge']
# Colonnes numériques : ['Unnamed: 0', 'patient_id', 'year_visit', 'heart_rate_signal', 'patient_age', 'temperature_signal', 'respiratory_rate_signal', 'blood_pressure_systolic_signal', 'blood_pressure_diastolic_signal', 'pulse_oximetry_signal']

# %%
#Créer le prétraitement automatique
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

preprocess = ColumnTransformer(
    transformers=[
        ("num", Pipeline(steps=[
            ("imputer", SimpleImputer(strategy="median")),
            ("scaler", StandardScaler())
        ]), num_cols),

        ("cat", Pipeline(steps=[
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("onehot", OneHotEncoder(handle_unknown="ignore"))
        ]), cat_cols)
    ]
)

# %%
#Séparer les données en entraînement et test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %% [markdown]
# # **Entraîner le modèle RandomForest**

# %%
# Construction de modèle + pipeline (prétraitement + modèle)
from sklearn.ensemble import RandomForestClassifier
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

rf_model = RandomForestClassifier(
    n_estimators=500,
    random_state=42,
    class_weight="balanced",
    n_jobs=-1
)

rf_pipe = Pipeline(steps=[
    ("preprocess", preprocess),     # imputation + scaling + onehot
    ("smote", SMOTE(random_state=42)),  # équilibre des classes
    ("model", rf_model)
])

# %%
# Entraîner le modèle
rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Unnamed: 0', 'patient_id',
#                                                    'year_visit',
#                                                    'heart_rate_signal',
#                                                    'patient_age',
#                                                    'temperature_signal',
#                                                    'respiratory_rate_signal',
#                                                    'blood_pressure_systolic_signal',
#                                                    'blood_pressure_diastolic_signal',
#                                                    'pu...
#                                                    'is_patient_suffer_HIV_infection',
#                                                    'is_patient_suffer_high_cholesterol',
#                                                    'is_patient_suffer_hyper_tension',
#                                                    'is_patient_suffer_obesity',
#                                                    'is_patient_suffer_apnea',
#                                                    'is_patient_suffer_osteoporosis',
#                                                    'medicament1', 'medicament2', ...])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         n_estimators=500, n_jobs=-1,
#                                         random_state=42))])

# %%
# Prédire sur le test
y_pred = rf_pipe.predict(X_test)

# %%
# Évaluer (Accuracy + F1 + matrice de confusion)
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1-macro:", f1_score(y_test, y_pred, average="macro"))

print("\nClassification report:\n", classification_report(y_test, y_pred))
print("\nConfusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7423312883435583
# F1-macro: 0.7466023255496941
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.64      0.67       108
#            1       0.97      0.79      0.87       109
#            2       0.63      0.80      0.70       109
#
#     accuracy                           0.74       326
#    macro avg       0.76      0.74      0.75       326
# weighted avg       0.76      0.74      0.75       326
#
#
# Confusion matrix:
#  [[69  2 37]
#  [ 9 86 14]
#  [21  1 87]]

# %%
# Sauvegarder le pipeline entraîné
import joblib

joblib.dump(rf_pipe, "rf_triage_pipeline.joblib")
# Out:
# ['rf_triage_pipeline.joblib']
